# %%
import numpy as np
  
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

n = int(input("Enter the size of the matrix: "))
# Out:
# Enter the size of the matrix: 100

# %%
is_good_enough = False
while not is_good_enough  :
    x = np.arange(1,n)
    V = []
    for i in range(n):
        y = np.random.randn(n)*2
        V.append(y)
    A = np.cov(V)
    is_good_enough = is_pos_def(A)

print ( is_pos_def(A))
print(A)
a = A
# Out:
# True
# [[ 3.42481491 -0.2232031   0.34219788 ...  0.08258208 -0.16648762
#    0.09074636]
#  [-0.2232031   3.69834156  0.82268796 ... -0.75005999  0.40603748
#    0.16881162]
#  [ 0.34219788  0.82268796  5.19107441 ... -0.32542988 -0.29640762
#   -0.16536684]
#  ...
#  [ 0.08258208 -0.75005999 -0.32542988 ...  3.88645973 -0.395344
#   -0.84926117]
#  [-0.16648762  0.40603748 -0.29640762 ... -0.395344    3.82450079
#   -0.07002418]
#  [ 0.09074636  0.16881162 -0.16536684 ... -0.84926117 -0.07002418
#    3.30787641]]

# %%
# %%time


import numpy as np 
def MatrixLambda (n, A,i,l): 
    for p in range(n+1):
        A[i][p]=A[i][p]*l        
    return A
def MatrixTwoLines (n, A,i,j): 
    for p in range(n+1):
        A[i][p]=A[i][p]-A[j][p]
    return A
def gauss(a,b,n):
    A =np.ones((n,n+1))
    for i in range (0,n):
        A[i][n]=b[i]
        for j in range(0,n):
            A[i][j]=a[i][j]
    for k in range (n):
        for i in range (n):
            if A[i][k] != 0:
                l=A[k][k]/A[i][k]
                MatrixLambda (n, A,i,l)
                if i !=k:
                    MatrixTwoLines (n, A,i,k)
    for p in range(n):
        MatrixLambda (n, A,p,1/A[p][p])
    return A
b=np.ones((n,1))
l = np.zeros((n,n))
l[0][0] = a[0][0]**(0.5)
h = 0
m = 0
for  i in range(1,n):
    for j in range (n):
        if j <= i:
            h = 0
            s = 0
            if i == j:
                for m in range(j):
                    if j == 0:
                        h = 0
                    else:
                        h = h + l[i][m]**2
                l[i][j] = (a[i][j] - h)**(0.5)
            else:
                for m in range(j):
                    if j == 0:
                        s =0
                    else:
                        s = s + l[i][m]*l[j][m]
                l[i][j] = (a[i][j] - s)/l[j][j]
lt=np.transpose(l)
y1 = gauss(l,b,n)
y = np.zeros((n,1))
for k in range(n):
    y[k][0] = y1[k][n]
x1 = gauss(lt,y,n)
x = np.zeros((n,1))
for k in range(n):
    x[k][0] = x1[k][n]
print(x)
# Out:
# [[-3.53734513e+14]
#  [-2.91731601e+11]
#  [-3.20471246e+14]
#  [-5.80555977e+14]
#  [-9.68090925e+14]
#  [ 9.19750548e+14]
#  [ 9.44490360e+14]
#  [ 7.57055677e+14]
#  [-3.70276945e+14]
#  [ 2.33278751e+15]
#  [ 9.34241086e+14]
#  [ 7.36513450e+14]
#  [-7.87669075e+14]
#  [ 6.78512950e+14]
#  [-4.29601591e+14]
#  [-8.31481061e+13]
#  [ 6.52730584e+14]
#  [ 3.02036803e+14]
#  [ 1.49638282e+15]
#  [-3.94052309e+14]
#  [-1.30439341e+14]
#  [-8.88987885e+14]
#  [ 1.86132099e+14]
#  [ 8.18109834e+14]
#  [-5.96848477e+14]
#  [-1.68717009e+14]
#  [ 7.34294085e+14]
#  [ 1.00733388e+15]
#  [ 9.30844488e+14]
#  [ 8.02078603e+13]
#  [ 4.55517056e+14]
#  [ 2.79845264e+14]
#  [ 2.47885054e+15]
#  [-4.43395265e+14]
#  [ 1.79925540e+14]
#  [ 4.01167930e+14]
#  [ 4.00743613e+14]
#  [-3.93650976e+14]
#  [ 7.35639137e+14]
#  [ 8.89882338e+14]
#  [-1.22558094e+15]
#  [-4.75892609e+14]
#  [-3.75929499e+14]
#  [-1.25636887e+15]
#  [ 3.89762471e+13]
#  [-6.18631431e+14]
#  [ 9.21819936e+14]
#  [ 8.18629461e+14]
#  [ 2.28897585e+14]
#  [ 2.28905589e+14]
#  [-1.72501074e+14]
#  [ 3.08531426e+14]
#  [-5.19627334e+14]
#  [-1.02311208e+15]
#  [ 1.29451983e+14]
#  [-4.29007200e+14]
#  [ 3.48066602e+14]
#  [-3.81116500e+13]
#  [-4.92786228e+14]
#  [ 7.71520917e+14]
#  [-6.61683445e+14]
#  [-8.42389315e+14]
#  [ 6.17429623e+14]
#  [ 8.66777314e+13]
#  [ 3.04822387e+14]
#  [ 6.45773456e+14]
#  [-1.76431016e+15]
#  [ 3.11638338e+14]
#  [-4.29849429e+14]
#  [ 6.50037339e+14]
#  [ 1.06968436e+15]
#  [ 1.24124403e+15]
#  [-7.16556163e+14]
#  [ 5.50128988e+14]
#  [ 6.66783505e+14]
#  [ 5.91191131e+14]
#  [ 1.32529995e+14]
#  [-3.59499684e+14]
#  [ 5.89835217e+14]
#  [-4.85946969e+14]
#  [ 5.49383662e+14]
#  [-8.76493752e+14]
#  [ 8.13063130e+14]
#  [ 3.89538247e+12]
#  [ 5.25501258e+14]
#  [-2.52404855e+14]
#  [-5.37944798e+14]
#  [-6.40688633e+14]
#  [ 2.80322629e+14]
#  [-7.70655014e+14]
#  [ 1.34676180e+15]
#  [ 5.78646912e+14]
#  [ 3.07552237e+14]
#  [ 6.47583237e+14]
#  [ 4.68386213e+14]
#  [-6.19774926e+14]
#  [-2.34087528e+14]
#  [-7.62487869e+14]
#  [ 7.90486366e+13]
#  [-9.15056935e+13]]
# CPU times: total: 1.7 s
# Wall time: 1.72 s
