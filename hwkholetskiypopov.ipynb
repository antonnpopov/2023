# %%
import numpy as np
  
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

n = int(input("Enter the size of the matrix: "))
# Out:
# Enter the size of the matrix: 100

# %%
is_good_enough = False
while not is_good_enough  :
    x = np.arange(1,n)
    V = []
    for i in range(n):
        y = np.random.randn(n)*2
        V.append(y)
    A = np.cov(V)
    is_good_enough = is_pos_def(A)

print ( is_pos_def(A))
print(A)
a = A
# Out:
# True
# [[ 5.14360749  0.12670434 -0.11931466 ...  0.32416441 -0.53523162
#   -0.17951913]
#  [ 0.12670434  3.89366615  0.12373371 ...  0.19799223 -0.19464322
#    0.01207808]
#  [-0.11931466  0.12373371  3.9566931  ...  0.14162145  0.00585207
#    0.26671807]
#  ...
#  [ 0.32416441  0.19799223  0.14162145 ...  4.84344941 -1.23747646
#    0.15944923]
#  [-0.53523162 -0.19464322  0.00585207 ... -1.23747646  3.82759581
#   -0.07487682]
#  [-0.17951913  0.01207808  0.26671807 ...  0.15944923 -0.07487682
#    4.37038446]]

# %%
import numpy as np 
def MatrixLambda (n, A,i,l): 
    for p in range(n+1):
        A[i][p]=A[i][p]*l        
    return A
def MatrixTwoLines (n, A,i,j): 
    for p in range(n+1):
        A[i][p]=A[i][p]-A[j][p]
    return A
def gauss(a,b,n):
    A =np.ones((n,n+1))
    for i in range (0,n):
        A[i][n]=b[i]
        for j in range(0,n):
            A[i][j]=a[i][j]
    for k in range (n):
        for i in range (n):
            if A[i][k] != 0:
                l=A[k][k]/A[i][k]
                MatrixLambda (n, A,i,l)
                if i !=k:
                    MatrixTwoLines (n, A,i,k)
    for p in range(n):
        MatrixLambda (n, A,p,1/A[p][p])
    return A
b=np.ones((n,1))
l = np.zeros((n,n))
l[0][0] = a[0][0]**(0.5)
h = 0
m = 0
for  i in range(1,n):
    for j in range (n):
        if j <= i:
            h = 0
            s = 0
            if i == j:
                for m in range(j):
                    if j == 0:
                        h = 0
                    else:
                        h = h + l[i][m]**2
                l[i][j] = (a[i][j] - h)**(0.5)
            else:
                for m in range(j):
                    if j == 0:
                        s =0
                    else:
                        s = s + l[i][m]*l[j][m]
                l[i][j] = (a[i][j] - s)/l[j][j]
lt=np.transpose(l)
y1 = gauss(l,b,n)
y = np.zeros((n,1))
for k in range(n):
    y[k][0] = y1[k][n]
x1 = gauss(lt,y,n)
x = np.zeros((n,1))
for k in range(n):
    x[k][0] = x1[k][n]
print(x)
# Out:
# [[ 3.83544758e+14]
#  [ 2.26884764e+14]
#  [-1.18337405e+15]
#  [ 8.04255836e+14]
#  [ 6.73024541e+14]
#  [-2.47448182e+13]
#  [ 1.62512150e+13]
#  [ 3.74029319e+14]
#  [ 1.45899441e+14]
#  [ 1.52542957e+14]
#  [ 2.76393109e+14]
#  [ 4.34736477e+14]
#  [-1.21838763e+15]
#  [-1.04656424e+14]
#  [-6.47103339e+14]
#  [ 4.78129951e+13]
#  [ 2.99204958e+14]
#  [ 2.85315328e+14]
#  [-3.19057472e+14]
#  [ 4.05638820e+14]
#  [ 4.83169802e+14]
#  [ 2.45303290e+14]
#  [ 3.08302732e+14]
#  [ 2.89551039e+13]
#  [ 3.30384542e+14]
#  [-3.28994441e+14]
#  [ 5.50998079e+14]
#  [ 5.67081934e+14]
#  [-1.08301656e+14]
#  [ 9.90680882e+12]
#  [-1.47639666e+14]
#  [ 7.31496538e+14]
#  [-9.57736909e+14]
#  [ 3.07794341e+13]
#  [ 7.06458392e+14]
#  [ 6.48513294e+14]
#  [ 1.55997077e+14]
#  [ 7.12914652e+14]
#  [-3.50636185e+14]
#  [-5.17417390e+14]
#  [ 1.79693158e+14]
#  [ 4.04939157e+14]
#  [-5.13845116e+14]
#  [-7.73773750e+13]
#  [-1.63959849e+14]
#  [ 2.53624497e+14]
#  [ 9.56091018e+13]
#  [ 3.84252670e+14]
#  [ 2.21886577e+14]
#  [ 8.53833081e+13]
#  [-1.22857464e+14]
#  [-2.97772484e+14]
#  [-2.28775249e+14]
#  [-3.30675139e+14]
#  [ 3.40738879e+14]
#  [-2.50636500e+14]
#  [-3.90105572e+14]
#  [ 1.56088488e+14]
#  [ 3.92069985e+14]
#  [-3.64199596e+14]
#  [-7.98697054e+13]
#  [-6.38651988e+12]
#  [ 2.19215800e+14]
#  [-1.40837322e+14]
#  [ 4.42587690e+14]
#  [ 3.66470262e+14]
#  [ 9.30526186e+13]
#  [-1.51436104e+14]
#  [-4.96331898e+14]
#  [ 4.82151985e+14]
#  [ 3.34055112e+14]
#  [ 1.29232840e+14]
#  [ 2.13761203e+14]
#  [ 3.08769517e+14]
#  [-4.78411147e+14]
#  [ 1.58843439e+14]
#  [ 3.29760649e+14]
#  [-4.15956882e+14]
#  [-5.38378069e+14]
#  [-3.17881645e+14]
#  [ 4.54804038e+13]
#  [ 1.28509013e+14]
#  [-5.31268427e+14]
#  [-1.09759085e+14]
#  [-1.06565362e+13]
#  [-6.67431495e+14]
#  [ 2.54686149e+13]
#  [-5.42559805e+14]
#  [-2.51018532e+14]
#  [-2.43576307e+14]
#  [-8.56438441e+13]
#  [-1.79072637e+14]
#  [-1.25267718e+14]
#  [ 1.35217426e+14]
#  [-1.03537753e+14]
#  [-2.74196182e+14]
#  [-2.60183763e+14]
#  [-1.92773619e+14]
#  [-7.08088004e+14]
#  [ 2.60839360e+14]]
